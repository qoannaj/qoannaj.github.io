# %% [markdown]
# <a href="https://colab.research.google.com/github/qoannaj/qoannaj.github.io/blob/main/docs/notebooks/Training_and_inference_using_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training and inference on your own data using Google Drive

# %% [markdown]
# In this notebook we'll install SLEAP, import training data into Colab using [Google Drive](https://www.google.com/drive), and run training and inference.

# %% [markdown]
# ## Install SLEAP
# Note: Before installing SLEAP check [SLEAP releases](https://github.com/talmolab/sleap/releases) page for the latest version.

# %%
# !pip uninstall -qqq -y opencv-python opencv-contrib-python
# !pip install -qqq "sleap[pypi]>=1.3.3"
# Out:
# WARNING: sleap 1.5.2 does not provide the extra 'pypi'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.5 MB/s eta 0:00:00

# %%
# !pip install "sleap[nn]" --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting sleap[nn]
#   Downloading sleap-1.5.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (25.4.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.3.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (0.6.0)
# Collecting imgstore (from sleap[nn])
#   Downloading imgstore-0.3.7-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting jsmin (from sleap[nn])
#   Downloading jsmin-3.0.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (4.1.1)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (3.0.3)
# Collecting ndx-pose (from sleap[nn])
#   Downloading ndx_pose-0.2.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (3.6.1)
# Collecting nixio (from sleap[nn])
#   Downloading nixio-1.5.4.tar.gz (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (4.12.0.88)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (5.9.5)
# Collecting pykalman (from sleap[nn])
#   Downloading pykalman-0.11.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting pynwb (from sleap[nn])
#   Downloading pynwb-3.1.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting PySide6 (from sleap[nn])
#   Downloading pyside6-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (5.3 kB)
# Collecting python-rapidjson (from sleap[nn])
#   Downloading python_rapidjson-1.23-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (6.0.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (26.2.1)
# Collecting qtpy (from sleap[nn])
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (13.9.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (0.13.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.5.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.0.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from sleap[nn]) (3.10.0)
# Collecting sleap-io>=0.5.7 (from sleap-io[all]>=0.5.7->sleap[nn])
#   Downloading sleap_io-0.5.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting sleap-nn>=0.0.4 (from sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading sleap_nn-0.0.5-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: h5py>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn]) (3.15.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn]) (3.20.2)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn]) (2025.10.16)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn]) (4.67.1)
# Collecting rich_click (from sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn])
#   Downloading rich_click-1.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting hdmf>=3.13.0 (from ndx-pose->sleap[nn])
#   Downloading hdmf-4.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from pynwb->sleap[nn]) (4.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pynwb->sleap[nn]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->sleap[nn]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->sleap[nn]) (2025.2)
# Collecting av<16.0.0 (from sleap-io[all]>=0.5.7->sleap[nn])
#   Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting pymatreader (from sleap-io[all]>=0.5.7->sleap[nn])
#   Downloading pymatreader-1.1.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting lightning (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.6 MB/s eta 0:00:00
# Collecting kornia (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.23.1)
# Collecting loguru (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting hydra-core (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting jupyter (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting jupyterlab (from sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading jupyterlab-4.5.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.9.0+cu126)
# Collecting torchvision<0.24.0,>=0.20.0 (from sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.23.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->sleap[nn]) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->sleap[nn]) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->sleap[nn]) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->sleap[nn]) (4.4.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->sleap[nn]) (6.5.3)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio->sleap[nn]) (11.3.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from imgstore->sleap[nn]) (5.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sleap[nn]) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nixio->sleap[nn]) (1.17.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->sleap[nn]) (4.9.3)
# Collecting scikit-base<0.14.0 (from pykalman->sleap[nn])
#   Downloading scikit_base-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting shiboken6==6.10.1 (from PySide6->sleap[nn])
#   Downloading shiboken6-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (2.5 kB)
# Collecting PySide6_Essentials==6.10.1 (from PySide6->sleap[nn])
#   Downloading pyside6_essentials-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (3.7 kB)
# Collecting PySide6_Addons==6.10.1 (from PySide6->sleap[nn])
#   Downloading pyside6_addons-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sleap[nn]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sleap[nn]) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sleap[nn]) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->sleap[nn]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->sleap[nn]) (2.19.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->sleap[nn]) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sleap[nn]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sleap[nn]) (3.6.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from hdmf>=3.13.0->ndx-pose->sleap[nn]) (4.25.1)
# Collecting ruamel-yaml>=0.16 (from hdmf>=3.13.0->ndx-pose->sleap[nn])
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->sleap[nn]) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->sleap[nn]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->sleap[nn]) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->sleap[nn]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->sleap[nn]) (0.4.2)
# Collecting torch (from sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2025.3.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (7.7.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.28.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (5.9.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.5.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (5.7.1)
# Collecting kornia_rs>=0.1.9 (from kornia->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting pytorch-lightning (from lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting xmltodict (from pymatreader->sleap-io[all]>=0.5.7->sleap[nn])
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.12/dist-packages (from rich_click->sleap-io>=0.5.7->sleap-io[all]>=0.5.7->sleap[nn]) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.1.45)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (5.29.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.47.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.16.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.6.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf>=3.13.0->ndx-pose->sleap[nn]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf>=3.13.0->ndx-pose->sleap[nn]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf>=3.13.0->ndx-pose->sleap[nn]) (0.30.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.5.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml>=0.16->hdmf>=3.13.0->ndx-pose->sleap[nn])
#   Downloading ruamel_yaml_clib-0.2.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.0.16)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.0.52)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.22.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (5.0.2)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.2.14)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (0.8.5)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->sleap-nn>=0.0.4->sleap-nn[torch]>=0.0.4; extra == "nn"->sleap[nn]) (1.4.0)
# Downloading sleap_io-0.5.7-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.3/314.3 kB 30.4 MB/s eta 0:00:00
# Downloading ndx_pose-0.2.2-py3-none-any.whl (15 kB)
# Downloading pynwb-3.1.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.7 MB/s eta 0:00:00
# Downloading sleap_nn-0.0.5-py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 21.8 MB/s eta 0:00:00
# Downloading imgstore-0.3.7-py2.py3-none-any.whl (911 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.5/911.5 kB 60.0 MB/s eta 0:00:00
# Downloading pykalman-0.11.0-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.4/249.4 kB 25.5 MB/s eta 0:00:00
# Downloading pyside6-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.8/557.8 kB 40.3 MB/s eta 0:00:00
# Downloading pyside6_addons-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl (170.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 MB 5.9 MB/s eta 0:00:00
# Downloading pyside6_essentials-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl (76.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.8/76.8 MB 10.5 MB/s eta 0:00:00
# Downloading shiboken6-6.10.1-cp39-abi3-manylinux_2_34_x86_64.whl (271 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 kB 23.1 MB/s eta 0:00:00
# Downloading python_rapidjson-1.23-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 46.7 MB/s eta 0:00:00
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 9.3 MB/s eta 0:00:00
# Downloading sleap-1.5.2-py3-none-any.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.3/883.3 kB 43.0 MB/s eta 0:00:00
# Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 21.2 MB/s eta 0:00:00
# Downloading hdmf-4.1.2-py3-none-any.whl (339 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.5/339.5 kB 31.5 MB/s eta 0:00:00
# Downloading scikit_base-0.13.0-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 16.9 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.23.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 55.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl (183.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 MB 5.9 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.9 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyterlab-4.5.1-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 130.8 MB/s eta 0:00:00
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.9 MB/s eta 0:00:00
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 61.6 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.4 MB/s eta 0:00:00
# Downloading pymatreader-1.1.0-py3-none-any.whl (9.5 kB)
# Downloading rich_click-1.9.4-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 7.8 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 8.6 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.3 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 118.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 14.5 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 72.2 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 70.5 MB/s eta 0:00:00
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading ruamel_yaml_clib-0.2.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (788 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 66.7 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.0 MB/s eta 0:00:00
# Building wheels for collected packages: jsmin, nixio
#   Building wheel for jsmin (setup.py) ... done
#   Created wheel for jsmin: filename=jsmin-3.0.1-py3-none-any.whl size=13765 sha256=a684c18aabf4997eec49e9b16104f4973f3bae95691e2860874afdaf9ee6d536
#   Stored in directory: /root/.cache/pip/wheels/05/f8/07/b3579be7c148b787938780bc19f9a0afb51fbe9b89bcd3e2ea
#   Building wheel for nixio (setup.py) ... done
#   Created wheel for nixio: filename=nixio-1.5.4-py3-none-any.whl size=87927 sha256=9fe94670b462d1d059c3f66661c7624f92016592a7d9d765cf6d429266fa3d26
#   Stored in directory: /root/.cache/pip/wheels/9b/1d/76/1abd6ceaa9258868c846daefc4ba7a9494d6383af9ad779f66
# Successfully built jsmin nixio
# Installing collected packages: jsmin, xmltodict, shiboken6, scikit-base, ruamel.yaml.clib, qtpy, python-rapidjson, loguru, lightning-utilities, kornia_rs, json5, jedi, av, async-lru, torch, ruamel-yaml, PySide6_Essentials, pymatreader, pykalman, nixio, hydra-core, torchvision, torchmetrics, rich_click, PySide6_Addons, kornia, imgstore, pytorch-lightning, PySide6, hdmf, pynwb, lightning, ndx-pose, sleap-io, jupyterlab-server, jupyter-lsp, sleap, jupyterlab, jupyter, sleap-nn
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cu126
#     Uninstalling torch-2.9.0+cu126:
#       Successfully uninstalled torch-2.9.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu126
#     Uninstalling torchvision-0.24.0+cu126:
#       Successfully uninstalled torchvision-0.24.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.9.0+cu126 requires torch==2.9.0, but you have torch 2.8.0+cpu which is incompatible.
# Successfully installed PySide6-6.10.1 PySide6_Addons-6.10.1 PySide6_Essentials-6.10.1 async-lru-2.0.5 av-15.1.0 hdmf-4.1.2 hydra-core-1.3.2 imgstore-0.3.7 jedi-0.19.2 jsmin-3.0.1 json5-0.12.1 jupyter-1.1.1 jupyter-lsp-2.3.0 jupyterlab-4.5.1 jupyterlab-server-2.28.0 kornia-0.8.2 kornia_rs-0.1.10 lightning-2.6.0 lightning-utilities-0.15.2 loguru-0.7.3 ndx-pose-0.2.2 nixio-1.5.4 pykalman-0.11.0 pymatreader-1.1.0 pynwb-3.1.3 python-rapidjson-1.23 pytorch-lightning-2.6.0 qtpy-2.4.3 rich_click-1.9.4 ruamel-yaml-0.18.16 ruamel.yaml.clib-0.2.15 scikit-base-0.13.0 shiboken6-6.10.1 sleap-1.5.2 sleap-io-0.5.7 sleap-nn-0.0.5 torch-2.8.0+cpu torchmetrics-1.8.2 torchvision-0.23.0+cpu xmltodict-1.0.2

# %% [markdown]
# ## Import training data into Colab with Google Drive
# We'll first prepare and export the training data from SLEAP, then upload it to Google Drive, and then mount Google Drive  into this Colab notebook.

# %% [markdown]
# ### Create and export the training job package
# A self-contained **training job package** contains a .slp file with labeled data and images which will be used for training, as well as .json training configuration file(s).
#
# A training job package can be exported in the SLEAP GUI fron the "Run Training.." dialog under the "Predict" menu.

# %% [markdown]
# ### Upload training job package to Google Drive
# To be consistent with the examples in this notebook, name the SLEAP project `colab` and create a directory called `sleap` in the root of your Google Drive. Then upload the exported training job package `colab.slp.training_job.zip` into `sleap` directory.
#
# If you place your training pckage somewhere else, or name it differently, adjust the paths/filenames/parameters below accordingly.

# %% [markdown]
# ### Mount your Google Drive
# Mounting your Google Drive will allow you to accessed the uploaded training job package in this notebook. When prompted to log into your Google account, give Colab access and the copy the authorization code into a field below (+ hit 'return').

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Let's set your current working directory to the directory with your training job package and unpack it there. Later on the output from training (i.e., the models) and from interence (i.e., predictions) will all be saved in this directory as well.

# %%
import os
os.chdir("/content/drive/My Drive/sleap")
# !unzip colab.slp.training_job.zip
# !ls

# %% [markdown]
# ## Train a model
#
# Let's train a model with the training profile (.json file) and the project data (.slp file) you have exported from SLEAP.
#
#
# ### Note on training profiles
# Depending on the pipeline you chose in the training dialog, the config filename(s) will be:
#
# - for a **bottom-up** pipeline approach: `multi_instance.json` (this is the pipeline we assume here),
#
# - for a **top-down** pipeline, you'll have a different profile for each of the models: `centroid.json` and `centered_instance.json`,
#
# - for a **single animal** pipeline: `single_instance.json`.
#
#
# ### Note on training process
# When you start training, you'll first see the training parameters and then the training and validation loss for each training epoch.
#
# As soon as you're satisfied with the validation loss you see for an epoch during training, you're welcome to stop training by clicking the stop button. The version of the model with the lowest validation loss is saved during training, and that's what will be used for inference.
#
# If you don't stop training, it will run for 200 epochs or until validation loss fails to improve for some number of epochs (controlled by the early_stopping fields in the training profile).

# %%
# !sleap-train "/content/drive/MyDrive/sleap_project/single_instance.yaml" "/content/drive/MyDrive/sleap_project/labels.v002trained.slp" --run_name "my_model"
# Out:
# /bin/bash: line 1: sleap-train: command not found

# %% [markdown]
# If instead of bottom-up you've chosen the top-down pipeline (with two training configs), you would need to invoke two separate training jobs in sequence:
#
# - `!sleap-train centroid.json colab.pkg.slp`
# - `!sleap-train centered_instance.json colab.pkg.slp`

# %% [markdown]
# ## Run inference to predict instances
#
# Once training finishes, you'll see a new directory (or two new directories for top-down training pipeline) containing all the model files SLEAP needs to use for inference.
#
# Here we'll use the created model files to run inference in two modes:
#
# - predicting instances in suggested frames from the exported .slp file
#
# - predicting and tracking instances in uploaded video
#
# You can also download the trained models for running inference from the SLEAP GUI on your computer (or anywhere else).
#
# ### Predicting instances in suggested frames
# This mode of predicting instances is useful for accelerating the manual labeling work; it allows you to get early predictions on suggested frames and merge them back into the project for faster labeling.
#
# Here we assume you've trained a bottom-up model and that the model files were written in directory named `colab_demo.bottomup`; later in this notebook we'll also show how to run inference with the pair of top-down models instead.

# %%
# !sleap-track \
    -m colab_demo.bottomup \
    --only-suggested-frames \
    -o colab.predicted_suggestions.slp \
    colab.pkg.slp

# %% [markdown]
# Now, you can download the generated `colab.predicted_suggestions.slp` file and merge it into your labeling project (**File -> Merge into Project...** from the GUI) to get new predictions for your suggested frames.

# %% [markdown]
# ### Predicting and tracking instances in uploaded video
# Let's first upload the video we want to run inference on and name it `colab_demo.mp4`. (If your video is not named `colab_demo.mp4`, adjust the names below accordingly.)
#
# For this demo we'll just get predictions for the first 200 frames (or you can adjust the --frames parameter below or remove it to run on the whole video).

# %%
# !sleap-track colab_demo.mp4 \
    --frames 0-200 \
    --tracking.tracker simple \
    -m colab_demo.bottomup

# %% [markdown]
# When inference is finished, it will save the predictions in a file which can be opened in the GUI as a SLEAP project file. The file will be in the same directory as the video and the filename will be `{video filename}.predictions.slp`.
#
# Let's inspect the predictions file:

# %%
# !sleap-inspect colab_demo.mp4.predictions.slp

# %% [markdown]
# You can copy this file from your Google Drive to a local drive and open it in the SLEAP GUI app (or open it directly if you have your Google Drive mounted on your local machine). If the video is in the same directory as the predictions file, SLEAP will automatically find it; otherwise, you'll be prompted to locate the video (since the path to the video on your local machine will be different than the path to the video on Colab).

# %% [markdown]
# ### Inference with top-down models
#
# If you trained the pair of models needed for top-down inference, you can call `sleap-track` with `-m path/to/model` for each model, like so:

# %%
# !sleap-track colab_demo.mp4 \
    --frames 0-200 \
    --tracking.tracker simple \
    -m colab_demo.centered_instance \
    -m colab_demo.centroid
